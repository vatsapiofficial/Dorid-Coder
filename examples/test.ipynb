// %% [markdown]
// # Sample Notebook
// This is a test notebook for Dorid-Coder.

// %%
console.log('Hello from Dorid-Coder!');
const a = 10;
const b = 20;
console.log('Sum:', a + b);

// %%
function greet(name) {
  return `Hello, ${name}!`;
}
console.log(greet('Developer'));
