// %% [markdown]
// # WebAssembly Example
// This notebook demonstrates the built-in WebAssembly support in Dorid-Coder.

// %%
console.log('WebAssembly Global:', typeof WebAssembly);
console.log('Wasm Toolkit (wasm):', typeof wasm);
console.log('WebAssemblyJS:', typeof webassemblyjs);

// %%
// Simple WASM module: (module)
const bytes = new Uint8Array([0, 97, 115, 109, 1, 0, 0, 0]);
WebAssembly.instantiate(bytes).then(result => {
  console.log('WASM instantiated successfully!');
}).catch(err => {
  console.error('WASM instantiation failed:', err);
});
